# %%
print("Hello good evening")
# Out:
# Hello good evening

# %% [markdown]
# This is my first program

# %% [raw]
# ,vakdfnclsndv
# vjdbvlnfs.v
# vcjhdabv,ksfn. b
# vvdksvlksfd;lv

# %%
comments:
this are the part of code but wont execute at runtime
there are two types comments:
1. single line comment
     # single line comment represented by hash

2. multi line comment
    ''' multi line comment ''' or """    """

# %%
keywords:
this are resreved words used for particular task and 
we cannot use these words are identifiers
(varibale name or function names)

ex: def, if, else, for, True, False ....etc

# %%
# intput/output function
print("how are you?") #output function
# Out:
# how are you?

# %%
# my name is priyanka, i am from Karnataka
n = input("enter your name")
p = input("enter your place")

#general printing statement
print("my name is",n,",i am from",p)
# Out:
# enter your name priyanka
# enter your place karnataka
# my name is priyanka ,i am from karnataka

# %%
#.format method
print("my name is {}, i am from {}".format(n,p))
# Out:
# my name is priyanka, i am from karnataka

# %%
# f string method
print(f"my name is {n}, i am from {p}")
# Out:
# my name is priyanka, i am from karnataka

# %%
num = 15
print(num)
# Out:
# 15

# %%
a = 45.7812345
variable:
it is place to store the values with specific 
variable name

valid variable declaration:
A = 6
b = 12
num = 123
stu_name = "priyanka"
Num1 = 234
Num2 = 987
_sub_marks = 79

invalid variable declarations:
1num = 78
stu id = 1234
@name$ = "kavya"

# %%
A = 6
b = 12
num = 123
stu_name = "priyanka"
Num1 = 234
Num2 = 987
_sub_marks = 79

# %%
Num1
# Out:
# 234

# %%
print(Num1,Num2)
# Out:
# 234 987

# %%
1num = 78
stu id = 1234
@name$ = "kavya"
# Out:
#   Cell In[15], line 3
#     @name$ = "kavya"
#          ^
# SyntaxError: invalid syntax
